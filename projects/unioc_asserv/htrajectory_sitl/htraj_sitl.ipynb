# %%
import os,scipy

os.system("make clean; make; ./main > /tmp/hitldata")

open('/tmp/hitldata','r').read()
data= scipy.genfromtxt('/tmp/hitldata', delimiter=',', names=('x','y','a','xsp','ysp'))

#plot(data['x'])
#plot(data['y']):
plot(data['xsp'],'+')
plot(data['x'],'+')
show()
plot(data['ysp'],'+')
plot(data['y'],'+')
show()

plot(data['x'],data['y'],'+')
